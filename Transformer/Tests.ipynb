# %%
from Net import *
import random
import numpy as np

test_vec = np.random.randn(1,10)
softmax = Softmax()
softmax.forward(test_vec)
# Out:
# array([[0.25628526, 0.0552673 , 0.11155497, 0.16519384, 0.02222549,
#         0.06152472, 0.07244118, 0.09533799, 0.137952  , 0.02221725]])

# %%
softmax.backward(np.random.random(), 0.1)
# Out:
# array([[ 0.08057206, -0.00598751, -0.01208557, -0.01789666, -0.00240785,
#         -0.00666542, -0.00784808, -0.01032866, -0.01494535, -0.00240696],
#        [-0.00598751,  0.02207149, -0.00260622, -0.00385937, -0.00051925,
#         -0.00143738, -0.00169242, -0.00222735, -0.00322293, -0.00051905],
#        [-0.01208557, -0.00260622,  0.04189613, -0.00779   , -0.00104808,
#         -0.0029013 , -0.00341609, -0.00449582, -0.00650536, -0.00104769],
#        [-0.01789666, -0.00385937, -0.00779   ,  0.05829535, -0.00155203,
#         -0.00429633, -0.00505864, -0.00665755, -0.00963333, -0.00155145],
#        [-0.00240785, -0.00051925, -0.00104808, -0.00155203,  0.00918638,
#         -0.00057804, -0.0006806 , -0.00089572, -0.00129609, -0.00020874],
#        [-0.00666542, -0.00143738, -0.0029013 , -0.00429633, -0.00057804,
#          0.0244077 , -0.00188404, -0.00247953, -0.00358783, -0.00057782],
#        [-0.00784808, -0.00169242, -0.00341609, -0.00505864, -0.0006806 ,
# ...

# %%
import numpy as np
from Layers import *
from utils import *
#Arbitrary sequence
temperatures = np.array([32.1, 33.5, 34.5, 32.9, 33.0, 33.6, 33.1, 32.4])
x_train = temperatures[:-1]
y_train = temperatures[-1]

# %%
network = [RNN(len(x_train), 10, 1)]
train(network, mse, mse_prime, x_train, y_train, epochs = 20, learning_rate=0.005, verbose=True)
# Out:
# Epoch 1/20, Training Loss = 1225.3775516854746
# Predicted temperature: -2.6, Real temperature: 32.4
# Epoch 2/20, Training Loss = 0.9148306601196795
# Predicted temperature: 31.4, Real temperature: 32.4
# Epoch 3/20, Training Loss = 0.09390864671898677
# Predicted temperature: 32.7, Real temperature: 32.4
# Epoch 4/20, Training Loss = 0.009822997496113777
# Predicted temperature: 32.3, Real temperature: 32.4
# Epoch 5/20, Training Loss = 0.000354708713066634
# Predicted temperature: 32.4, Real temperature: 32.4
# Epoch 6/20, Training Loss = 1.2808629179498788e-05
# Predicted temperature: 32.4, Real temperature: 32.4
# Epoch 7/20, Training Loss = 4.625225059394675e-07
# Predicted temperature: 32.4, Real temperature: 32.4
# Epoch 8/20, Training Loss = 1.6701796845299594e-08
# Predicted temperature: 32.4, Real temperature: 32.4
# Epoch 9/20, Training Loss = 6.031057967467423e-10
# Predicted temperature: 32.4, Real temperature: 32.4
# Epoch 10/20, Training Loss = 2.1778291762723397e-11
# Predicted temperature: 32.4, Real temperature: 32.4
# Epoch 11/20, Training Loss = 7.864192219858974e-13
# Predicted temperature: 32.4, Real temperature: 32.4
# Epoch 12/20, Training Loss = 2.839778213943357e-14
# Predicted temperature: 32.4, Real temperature: 32.4
# Epoch 13/20, Training Loss = 1.0254504172446083e-15
# Predicted temperature: 32.4, Real temperature: 32.4
# Epoch 14/20, Training Loss = 3.702924705789816e-17
# Predicted temperature: 32.4, Real temperature: 32.4
# Epoch 15/20, Training Loss = 1.337132264110337e-18
# Predicted temperature: 32.4, Real temperature: 32.4
# Epoch 16/20, Training Loss = 4.828049752272509e-20
# Predicted temperature: 32.4, Real temperature: 32.4
# Epoch 17/20, Training Loss = 1.7431870135210392e-21
# Predicted temperature: 32.4, Real temperature: 32.4
# Epoch 18/20, Training Loss = 6.299219673435514e-23
# Predicted temperature: 32.4, Real temperature: 32.4
# Epoch 19/20, Training Loss = 2.269092129552202e-24
# Predicted temperature: 32.4, Real temperature: 32.4
# Epoch 20/20, Training Loss = 8.077935669463161e-26
# Predicted temperature: 32.4, Real temperature: 32.4
